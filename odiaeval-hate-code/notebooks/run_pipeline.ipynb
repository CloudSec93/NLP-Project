# %% [markdown]
# # OdiaEval hate-speech pipeline — Colab driver (thin)
#
# All logic lives in `src/*.py`. This notebook only clones the repo and calls the
# stage modules so the run is identical to `bash reproduce.sh` from a terminal.
# See `PROMPT.md` for the build spec and `CLAUDE.md` for the scope boundary.

# %%
# !git clone <this-repo> odiaeval-hate-task1
# %cd odiaeval-hate-task1
# !pip -q install -r requirements.txt

# %%
# Stage 0 — pinned-SHA manifest
# !python -m src.resolve_manifest

# %%
# Stages 1–7 — uncomment as they are built
# !python -m src.acquire
# !python -m src.extract
# !python -m src.label
# !python -m src.filter
# !python -m src.dedup
# !python -m src.balance_split
# !python -m src.report
